# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

print("Environment setup successful!")
# Out:
# Environment setup successful!

# %%
df = pd.read_csv("../data/neighbourhood-profiles-2016-140-model.csv")

# %%
df.head()
# Out:
#    _id                   Category                      Topic  \
# 0    1  Neighbourhood Information  Neighbourhood Information
# 1    2  Neighbourhood Information  Neighbourhood Information
# 2    3                 Population   Population and dwellings
# 3    4                 Population   Population and dwellings
# 4    5                 Population   Population and dwellings
#
#                       Data Source               Characteristic  \
# 0                 City of Toronto         Neighbourhood Number
# 1                 City of Toronto         TSNS2020 Designation
# 2  Census Profile 98-316-X2016001             Population, 2016
# 3  Census Profile 98-316-X2016001             Population, 2011
# 4  Census Profile 98-316-X2016001  Population Change 2011-2016
#
#   City of Toronto Agincourt North Agincourt South-Malvern West  \
# 0             NaN             129                          128
# 1             NaN  No Designation               No Designation
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2383 entries, 0 to 2382
# Columns: 146 entries, _id to Yorkdale-Glen Park
# dtypes: int64(1), object(145)
# memory usage: 2.7+ MB

# %%
df.isnull().sum()
# Out:
# _id                         0
# Category                    0
# Topic                       0
# Data Source                 0
# Characteristic              0
#                            ..
# Wychwood                   56
# Yonge-Eglinton             56
# Yonge-St.Clair             56
# York University Heights    56
# Yorkdale-Glen Park         56
# Length: 146, dtype: int64

# %%
df.describe(include='all')
# Out:
#                 _id  Category                     Topic  \
# count   2383.000000      2383                      2383
# unique          NaN        15                        49
# top             NaN  Language  Ethnic origin population
# freq            NaN       808                       279
# mean    1192.000000       NaN                       NaN
# std      688.057168       NaN                       NaN
# min        1.000000       NaN                       NaN
# 25%      596.500000       NaN                       NaN
# 50%     1192.000000       NaN                       NaN
# 75%     1787.500000       NaN                       NaN
# max     2383.000000       NaN                       NaN
#
#                            Data Source        Characteristic City of Toronto  \
# count                             2383                  2383            2376
# unique                               5                  1651            1527
# ...

# %%
profile = ProfileReport(df, title="Toronto Neighbourhood Profiles EDA Report")

# %%
profile.to_file("../reports/Toronto_EDA_Report.html")
# Out:
# ...
# 100%|██████████| 146/146 [00:11<00:00, 12.31it/s]
# C:\Users\ksalyamova\AppData\Roaming\Python\Python311\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# C:\Users\ksalyamova\AppData\Roaming\Python\Python311\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   .reset_index(name=duplicates_key)
# ...
